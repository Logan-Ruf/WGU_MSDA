# %%
import pandas as pd
import psycopg2

conn = psycopg2.connect(database="postgres", user="postgres", password="password", host="localhost", port=5432)

# %%
df = pd.read_csv('sales_records.csv')
df
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C    10/8/14  535113847
# 1          Cosmetics       Offline              L    2/22/15  874708545
# 2             Fruits       Offline              M    12/9/15  854349935
# 3      Personal Care        Online              M    9/17/14  892836844
# 4          Household       Offline              H     2/4/10  129280602
# ...              ...           ...            ...        ...        ...
# 99995         Cereal       Offline              L    8/26/12  836322486
# 99996           Meat       Offline              C    12/3/13  110449349
# 99997        Clothes        Online              M     8/7/13  193128764
# 99998      Cosmetics        Online              L    6/28/11  701597058
# 99999      Cosmetics       Offline              C     4/3/12  423403060
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0      10/23/14         934      152.58      97.44      142509.72    91008.96
# 1       2/27/15        4551      437.20     263.33     1989697.20  1198414.83
# 2       1/18/16        9986        9.33       6.92       93169.38    69103.12
# 3      10/12/14        9118       81.73      56.67      745214.14   516717.06
# 4        3/5/10        5858      668.27     502.54     3914725.66  2943879.32
# ...         ...         ...         ...        ...            ...         ...
# 99995   9/11/12        5263      205.70     117.11     1082599.10   616349.93
# 99996  12/10/13        3272      421.89     364.69     1380424.08  1193265.68
# 99997   8/31/13        9948      109.28      35.84     1087117.44   356536.32
# 99998    7/3/11        7015      437.20     263.33     3066958.00  1847259.95
# 99999   4/30/12        3229      437.20     263.33     1411718.80   850292.57
#
#        Total Profit
# 0          51500.76
# 1         791282.37
# 2          24066.26
# 3         228497.08
# 4         970846.34
# ...             ...
# 99995     466249.17
# 99996     187158.40
# 99997     730581.12
# 99998    1219698.05
# 99999     561426.23
#
# [100000 rows x 14 columns]

# %%
from psycopg2.extras import execute_values
region_list = df['Region'].unique().tolist()

cur = conn.cursor()
try:
    execute_values(
        cur,
        "INSERT INTO region (name) VALUES %s",
        [(region,) for region in region_list]
    )
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()

# %%
with conn.cursor() as cur:
    cur.execute("SELECT * FROM region")
    regions = [r for r in cur.fetchall()]
regions
# Out:
# [(1, 'Middle East and North Africa'),
#  (2, 'Central America and the Caribbean'),
#  (3, 'Sub-Saharan Africa'),
#  (4, 'Europe'),
#  (5, 'Asia'),
#  (6, 'Australia and Oceania'),
#  (7, 'North America')]

# %%
region_key_lookup = {region[1]: region[0] for region in regions}
country_map = {row['Country']: region_key_lookup[row['Region']] for index, row in df.iterrows()}
country_map
# Out:
# {'Azerbaijan': 1,
#  'Panama': 2,
#  'Sao Tome and Principe': 3,
#  'Belize': 2,
#  'Denmark': 4,
#  'Germany': 4,
#  'Turkey': 1,
#  'United Kingdom': 4,
#  'Kazakhstan': 5,
#  'Haiti': 2,
#  'Italy': 4,
#  'Malta': 4,
#  'Jordan': 1,
#  'Cambodia': 5,
#  'Saint Kitts and Nevis ': 2,
#  'Cameroon': 3,
#  'Bahrain': 1,
#  'Solomon Islands': 6,
#  'Monaco': 4,
#  'Comoros': 3,
#  'Iceland': 4,
#  'Zambia': 3,
#  'Egypt': 1,
#  'Togo': 3,
#  'Saudi Arabia': 1,
#  'Morocco': 1,
#  'Tunisia ': 1,
#  'Angola': 3,
#  'Vietnam': 5,
#  'Belarus': 4,
#  'Myanmar': 5,
#  'Lithuania': 4,
#  'Switzerland': 4,
#  'Antigua and Barbuda ': 2,
#  'Mongolia': 5,
#  'Greenland': 7,
#  'Eritrea': 3,
#  'Saint Vincent and the Grenadines': 2,
#  'Portugal': 4,
#  'Somalia': 1,
#  'Israel': 1,
#  'Dominica': 2,
#  'Luxembourg': 4,
#  'Singapore': 5,
#  'Cyprus': 4,
#  'Botswana': 3,
#  'Malawi': 3,
#  'Kyrgyzstan': 5,
#  'Macedonia': 4,
#  'Rwanda': 3,
#  'Cape Verde': 3,
#  'Pakistan': 1,
#  'Libya': 1,
#  'Bangladesh': 5,
#  'Benin': 3,
#  'Burundi': 3,
#  'China': 5,
#  'Albania': 4,
#  'Bulgaria': 4,
#  'Central African Republic': 3,
#  'Ukraine': 4,
#  'Uganda': 3,
#  'Ghana': 3,
#  'Namibia': 3,
#  'Republic of the Congo': 3,
#  'Netherlands': 4,
#  'Australia': 6,
#  'Montenegro': 4,
#  'Iraq': 1,
#  "Cote d'Ivoire": 3,
#  'Mexico': 7,
#  'Slovakia': 4,
#  'Afghanistan': 1,
#  'Indonesia': 5,
#  'Thailand': 5,
#  'Mali': 3,
#  'Lebanon': 1,
#  'South Korea': 5,
#  'United Arab Emirates': 1,
#  'Georgia': 4,
#  'Guinea-Bissau': 3,
#  'Saint Lucia': 2,
#  'Lesotho': 3,
#  'Mauritius ': 3,
#  'Sudan': 3,
#  'Japan': 5,
#  'Estonia': 4,
#  'Laos': 5,
#  'Belgium': 4,
#  'Bhutan': 5,
#  'United States of America': 7,
#  'Sweden': 4,
#  'Nepal': 5,
#  'Senegal': 3,
#  'Dominican Republic': 2,
#  'Ethiopia': 3,
#  'Djibouti': 3,
#  'The Bahamas': 2,
#  'Algeria': 1,
#  'Costa Rica': 2,
#  'Maldives': 5,
#  'Mauritania': 3,
#  'Liberia': 3,
#  'East Timor': 6,
#  'Uzbekistan': 5,
#  'South Africa': 3,
#  'Ireland': 4,
#  'India': 5,
#  'Swaziland': 3,
#  'Slovenia': 4,
#  'North Korea': 5,
#  'Tanzania': 3,
#  'Papua New Guinea': 6,
#  'Turkmenistan': 5,
#  'Grenada': 2,
#  'Greece': 4,
#  'Kiribati': 6,
#  'Iran': 1,
#  'South Sudan': 3,
#  'Guinea': 3,
#  'Trinidad and Tobago': 2,
#  'Vatican City': 4,
#  'Norway': 4,
#  'Kosovo': 4,
#  'Kuwait': 1,
#  'Tuvalu': 6,
#  'Nicaragua': 2,
#  'Croatia': 4,
#  'Czech Republic': 4,
#  'Sierra Leone': 3,
#  'Andorra': 4,
#  'Tonga': 6,
#  'Finland': 4,
#  'Cuba': 2,
#  'Syria': 1,
#  'El Salvador': 2,
#  'Moldova ': 4,
#  'Taiwan': 5,
#  'Mozambique': 3,
#  'Samoa ': 6,
#  'Fiji': 6,
#  'Democratic Republic of the Congo': 3,
#  'Gabon': 3,
#  'Hungary': 4,
#  'Kenya': 3,
#  'France': 4,
#  'Marshall Islands': 6,
#  'Bosnia and Herzegovina': 4,
#  'Russia': 4,
#  'Canada': 7,
#  'Qatar': 1,
#  'Sri Lanka': 5,
#  'Spain': 4,
#  'Latvia': 4,
#  'Romania': 4,
#  'Federated States of Micronesia': 6,
#  'Barbados': 2,
#  'Burkina Faso': 3,
#  'Chad': 3,
#  'The Gambia': 3,
#  'Philippines': 5,
#  'Armenia': 4,
#  'Zimbabwe': 3,
#  'Niger': 3,
#  'Madagascar': 3,
#  'Serbia': 4,
#  'Equatorial Guinea': 3,
#  'San Marino': 4,
#  'Tajikistan': 5,
#  'Oman': 1,
#  'Poland': 4,
#  'Nauru': 6,
#  'Palau': 6,
#  'Liechtenstein': 4,
#  'Vanuatu': 6,
#  'New Zealand': 6,
#  'Guatemala': 2,
#  'Nigeria': 3,
#  'Seychelles ': 3,
#  'Malaysia': 5,
#  'Brunei': 5,
#  'Jamaica': 2,
#  'Austria': 4,
#  'Honduras': 2,
#  'Yemen': 1}

# %%
country_data = [(country, region_id) for country, region_id in country_map.items()]
country_data
# Out:
# [('Azerbaijan', 1),
#  ('Panama', 2),
#  ('Sao Tome and Principe', 3),
#  ('Belize', 2),
#  ('Denmark', 4),
#  ('Germany', 4),
#  ('Turkey', 1),
#  ('United Kingdom', 4),
#  ('Kazakhstan', 5),
#  ('Haiti', 2),
#  ('Italy', 4),
#  ('Malta', 4),
#  ('Jordan', 1),
#  ('Cambodia', 5),
#  ('Saint Kitts and Nevis ', 2),
#  ('Cameroon', 3),
#  ('Bahrain', 1),
#  ('Solomon Islands', 6),
#  ('Monaco', 4),
#  ('Comoros', 3),
#  ('Iceland', 4),
#  ('Zambia', 3),
#  ('Egypt', 1),
#  ('Togo', 3),
#  ('Saudi Arabia', 1),
#  ('Morocco', 1),
#  ('Tunisia ', 1),
#  ('Angola', 3),
#  ('Vietnam', 5),
#  ('Belarus', 4),
#  ('Myanmar', 5),
#  ('Lithuania', 4),
#  ('Switzerland', 4),
#  ('Antigua and Barbuda ', 2),
#  ('Mongolia', 5),
#  ('Greenland', 7),
#  ('Eritrea', 3),
#  ('Saint Vincent and the Grenadines', 2),
#  ('Portugal', 4),
#  ('Somalia', 1),
#  ('Israel', 1),
#  ('Dominica', 2),
#  ('Luxembourg', 4),
#  ('Singapore', 5),
#  ('Cyprus', 4),
#  ('Botswana', 3),
#  ('Malawi', 3),
#  ('Kyrgyzstan', 5),
#  ('Macedonia', 4),
#  ('Rwanda', 3),
#  ('Cape Verde', 3),
#  ('Pakistan', 1),
#  ('Libya', 1),
#  ('Bangladesh', 5),
#  ('Benin', 3),
#  ('Burundi', 3),
#  ('China', 5),
#  ('Albania', 4),
#  ('Bulgaria', 4),
#  ('Central African Republic', 3),
#  ('Ukraine', 4),
#  ('Uganda', 3),
#  ('Ghana', 3),
#  ('Namibia', 3),
#  ('Republic of the Congo', 3),
#  ('Netherlands', 4),
#  ('Australia', 6),
#  ('Montenegro', 4),
#  ('Iraq', 1),
#  ("Cote d'Ivoire", 3),
#  ('Mexico', 7),
#  ('Slovakia', 4),
#  ('Afghanistan', 1),
#  ('Indonesia', 5),
#  ('Thailand', 5),
#  ('Mali', 3),
#  ('Lebanon', 1),
#  ('South Korea', 5),
#  ('United Arab Emirates', 1),
#  ('Georgia', 4),
#  ('Guinea-Bissau', 3),
#  ('Saint Lucia', 2),
#  ('Lesotho', 3),
#  ('Mauritius ', 3),
#  ('Sudan', 3),
#  ('Japan', 5),
#  ('Estonia', 4),
#  ('Laos', 5),
#  ('Belgium', 4),
#  ('Bhutan', 5),
#  ('United States of America', 7),
#  ('Sweden', 4),
#  ('Nepal', 5),
#  ('Senegal', 3),
#  ('Dominican Republic', 2),
#  ('Ethiopia', 3),
#  ('Djibouti', 3),
#  ('The Bahamas', 2),
#  ('Algeria', 1),
#  ('Costa Rica', 2),
#  ('Maldives', 5),
#  ('Mauritania', 3),
#  ('Liberia', 3),
#  ('East Timor', 6),
#  ('Uzbekistan', 5),
#  ('South Africa', 3),
#  ('Ireland', 4),
#  ('India', 5),
#  ('Swaziland', 3),
#  ('Slovenia', 4),
#  ('North Korea', 5),
#  ('Tanzania', 3),
#  ('Papua New Guinea', 6),
#  ('Turkmenistan', 5),
#  ('Grenada', 2),
#  ('Greece', 4),
#  ('Kiribati', 6),
#  ('Iran', 1),
#  ('South Sudan', 3),
#  ('Guinea', 3),
#  ('Trinidad and Tobago', 2),
#  ('Vatican City', 4),
#  ('Norway', 4),
#  ('Kosovo', 4),
#  ('Kuwait', 1),
#  ('Tuvalu', 6),
#  ('Nicaragua', 2),
#  ('Croatia', 4),
#  ('Czech Republic', 4),
#  ('Sierra Leone', 3),
#  ('Andorra', 4),
#  ('Tonga', 6),
#  ('Finland', 4),
#  ('Cuba', 2),
#  ('Syria', 1),
#  ('El Salvador', 2),
#  ('Moldova ', 4),
#  ('Taiwan', 5),
#  ('Mozambique', 3),
#  ('Samoa ', 6),
#  ('Fiji', 6),
#  ('Democratic Republic of the Congo', 3),
#  ('Gabon', 3),
#  ('Hungary', 4),
#  ('Kenya', 3),
#  ('France', 4),
#  ('Marshall Islands', 6),
#  ('Bosnia and Herzegovina', 4),
#  ('Russia', 4),
#  ('Canada', 7),
#  ('Qatar', 1),
#  ('Sri Lanka', 5),
#  ('Spain', 4),
#  ('Latvia', 4),
#  ('Romania', 4),
#  ('Federated States of Micronesia', 6),
#  ('Barbados', 2),
#  ('Burkina Faso', 3),
#  ('Chad', 3),
#  ('The Gambia', 3),
#  ('Philippines', 5),
#  ('Armenia', 4),
#  ('Zimbabwe', 3),
#  ('Niger', 3),
#  ('Madagascar', 3),
#  ('Serbia', 4),
#  ('Equatorial Guinea', 3),
#  ('San Marino', 4),
#  ('Tajikistan', 5),
#  ('Oman', 1),
#  ('Poland', 4),
#  ('Nauru', 6),
#  ('Palau', 6),
#  ('Liechtenstein', 4),
#  ('Vanuatu', 6),
#  ('New Zealand', 6),
#  ('Guatemala', 2),
#  ('Nigeria', 3),
#  ('Seychelles ', 3),
#  ('Malaysia', 5),
#  ('Brunei', 5),
#  ('Jamaica', 2),
#  ('Austria', 4),
#  ('Honduras', 2),
#  ('Yemen', 1)]

# %%
cur = conn.cursor()

try:
    execute_values(
        cur,
        "INSERT INTO country (name, region_id) VALUES %s",
        country_data
    )
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()

# %%
with conn.cursor() as cur:
    cur.execute("SELECT * FROM country")
    countries = {c[1]: c for c in cur.fetchall()}
countries
# Out:
# {'Azerbaijan': (1, 'Azerbaijan', 1),
#  'Panama': (2, 'Panama', 2),
#  'Sao Tome and Principe': (3, 'Sao Tome and Principe', 3),
#  'Belize': (4, 'Belize', 2),
#  'Denmark': (5, 'Denmark', 4),
#  'Germany': (6, 'Germany', 4),
#  'Turkey': (7, 'Turkey', 1),
#  'United Kingdom': (8, 'United Kingdom', 4),
#  'Kazakhstan': (9, 'Kazakhstan', 5),
#  'Haiti': (10, 'Haiti', 2),
#  'Italy': (11, 'Italy', 4),
#  'Malta': (12, 'Malta', 4),
#  'Jordan': (13, 'Jordan', 1),
#  'Cambodia': (14, 'Cambodia', 5),
#  'Saint Kitts and Nevis ': (15, 'Saint Kitts and Nevis ', 2),
#  'Cameroon': (16, 'Cameroon', 3),
#  'Bahrain': (17, 'Bahrain', 1),
#  'Solomon Islands': (18, 'Solomon Islands', 6),
#  'Monaco': (19, 'Monaco', 4),
#  'Comoros': (20, 'Comoros', 3),
#  'Iceland': (21, 'Iceland', 4),
#  'Zambia': (22, 'Zambia', 3),
#  'Egypt': (23, 'Egypt', 1),
#  'Togo': (24, 'Togo', 3),
#  'Saudi Arabia': (25, 'Saudi Arabia', 1),
#  'Morocco': (26, 'Morocco', 1),
#  'Tunisia ': (27, 'Tunisia ', 1),
#  'Angola': (28, 'Angola', 3),
#  'Vietnam': (29, 'Vietnam', 5),
#  'Belarus': (30, 'Belarus', 4),
#  'Myanmar': (31, 'Myanmar', 5),
#  'Lithuania': (32, 'Lithuania', 4),
#  'Switzerland': (33, 'Switzerland', 4),
#  'Antigua and Barbuda ': (34, 'Antigua and Barbuda ', 2),
#  'Mongolia': (35, 'Mongolia', 5),
#  'Greenland': (36, 'Greenland', 7),
#  'Eritrea': (37, 'Eritrea', 3),
#  'Saint Vincent and the Grenadines': (38,
#   'Saint Vincent and the Grenadines',
#   2),
#  'Portugal': (39, 'Portugal', 4),
#  'Somalia': (40, 'Somalia', 1),
#  'Israel': (41, 'Israel', 1),
#  'Dominica': (42, 'Dominica', 2),
#  'Luxembourg': (43, 'Luxembourg', 4),
#  'Singapore': (44, 'Singapore', 5),
#  'Cyprus': (45, 'Cyprus', 4),
#  'Botswana': (46, 'Botswana', 3),
#  'Malawi': (47, 'Malawi', 3),
#  'Kyrgyzstan': (48, 'Kyrgyzstan', 5),
#  'Macedonia': (49, 'Macedonia', 4),
#  'Rwanda': (50, 'Rwanda', 3),
#  'Cape Verde': (51, 'Cape Verde', 3),
#  'Pakistan': (52, 'Pakistan', 1),
#  'Libya': (53, 'Libya', 1),
#  'Bangladesh': (54, 'Bangladesh', 5),
#  'Benin': (55, 'Benin', 3),
#  'Burundi': (56, 'Burundi', 3),
#  'China': (57, 'China', 5),
#  'Albania': (58, 'Albania', 4),
#  'Bulgaria': (59, 'Bulgaria', 4),
#  'Central African Republic': (60, 'Central African Republic', 3),
#  'Ukraine': (61, 'Ukraine', 4),
#  'Uganda': (62, 'Uganda', 3),
#  'Ghana': (63, 'Ghana', 3),
#  'Namibia': (64, 'Namibia', 3),
#  'Republic of the Congo': (65, 'Republic of the Congo', 3),
#  'Netherlands': (66, 'Netherlands', 4),
#  'Australia': (67, 'Australia', 6),
#  'Montenegro': (68, 'Montenegro', 4),
#  'Iraq': (69, 'Iraq', 1),
#  "Cote d'Ivoire": (70, "Cote d'Ivoire", 3),
#  'Mexico': (71, 'Mexico', 7),
#  'Slovakia': (72, 'Slovakia', 4),
#  'Afghanistan': (73, 'Afghanistan', 1),
#  'Indonesia': (74, 'Indonesia', 5),
#  'Thailand': (75, 'Thailand', 5),
#  'Mali': (76, 'Mali', 3),
#  'Lebanon': (77, 'Lebanon', 1),
#  'South Korea': (78, 'South Korea', 5),
#  'United Arab Emirates': (79, 'United Arab Emirates', 1),
#  'Georgia': (80, 'Georgia', 4),
#  'Guinea-Bissau': (81, 'Guinea-Bissau', 3),
#  'Saint Lucia': (82, 'Saint Lucia', 2),
#  'Lesotho': (83, 'Lesotho', 3),
#  'Mauritius ': (84, 'Mauritius ', 3),
#  'Sudan': (85, 'Sudan', 3),
#  'Japan': (86, 'Japan', 5),
#  'Estonia': (87, 'Estonia', 4),
#  'Laos': (88, 'Laos', 5),
#  'Belgium': (89, 'Belgium', 4),
#  'Bhutan': (90, 'Bhutan', 5),
#  'United States of America': (91, 'United States of America', 7),
#  'Sweden': (92, 'Sweden', 4),
#  'Nepal': (93, 'Nepal', 5),
#  'Senegal': (94, 'Senegal', 3),
#  'Dominican Republic': (95, 'Dominican Republic', 2),
#  'Ethiopia': (96, 'Ethiopia', 3),
#  'Djibouti': (97, 'Djibouti', 3),
#  'The Bahamas': (98, 'The Bahamas', 2),
#  'Algeria': (99, 'Algeria', 1),
#  'Costa Rica': (100, 'Costa Rica', 2),
#  'Maldives': (101, 'Maldives', 5),
#  'Mauritania': (102, 'Mauritania', 3),
#  'Liberia': (103, 'Liberia', 3),
#  'East Timor': (104, 'East Timor', 6),
#  'Uzbekistan': (105, 'Uzbekistan', 5),
#  'South Africa': (106, 'South Africa', 3),
#  'Ireland': (107, 'Ireland', 4),
#  'India': (108, 'India', 5),
#  'Swaziland': (109, 'Swaziland', 3),
#  'Slovenia': (110, 'Slovenia', 4),
#  'North Korea': (111, 'North Korea', 5),
#  'Tanzania': (112, 'Tanzania', 3),
#  'Papua New Guinea': (113, 'Papua New Guinea', 6),
#  'Turkmenistan': (114, 'Turkmenistan', 5),
#  'Grenada': (115, 'Grenada', 2),
#  'Greece': (116, 'Greece', 4),
#  'Kiribati': (117, 'Kiribati', 6),
#  'Iran': (118, 'Iran', 1),
#  'South Sudan': (119, 'South Sudan', 3),
#  'Guinea': (120, 'Guinea', 3),
#  'Trinidad and Tobago': (121, 'Trinidad and Tobago', 2),
#  'Vatican City': (122, 'Vatican City', 4),
#  'Norway': (123, 'Norway', 4),
#  'Kosovo': (124, 'Kosovo', 4),
#  'Kuwait': (125, 'Kuwait', 1),
#  'Tuvalu': (126, 'Tuvalu', 6),
#  'Nicaragua': (127, 'Nicaragua', 2),
#  'Croatia': (128, 'Croatia', 4),
#  'Czech Republic': (129, 'Czech Republic', 4),
#  'Sierra Leone': (130, 'Sierra Leone', 3),
#  'Andorra': (131, 'Andorra', 4),
#  'Tonga': (132, 'Tonga', 6),
#  'Finland': (133, 'Finland', 4),
#  'Cuba': (134, 'Cuba', 2),
#  'Syria': (135, 'Syria', 1),
#  'El Salvador': (136, 'El Salvador', 2),
#  'Moldova ': (137, 'Moldova ', 4),
#  'Taiwan': (138, 'Taiwan', 5),
#  'Mozambique': (139, 'Mozambique', 3),
#  'Samoa ': (140, 'Samoa ', 6),
#  'Fiji': (141, 'Fiji', 6),
#  'Democratic Republic of the Congo': (142,
#   'Democratic Republic of the Congo',
#   3),
#  'Gabon': (143, 'Gabon', 3),
#  'Hungary': (144, 'Hungary', 4),
#  'Kenya': (145, 'Kenya', 3),
#  'France': (146, 'France', 4),
#  'Marshall Islands': (147, 'Marshall Islands', 6),
#  'Bosnia and Herzegovina': (148, 'Bosnia and Herzegovina', 4),
#  'Russia': (149, 'Russia', 4),
#  'Canada': (150, 'Canada', 7),
#  'Qatar': (151, 'Qatar', 1),
#  'Sri Lanka': (152, 'Sri Lanka', 5),
#  'Spain': (153, 'Spain', 4),
#  'Latvia': (154, 'Latvia', 4),
#  'Romania': (155, 'Romania', 4),
#  'Federated States of Micronesia': (156, 'Federated States of Micronesia', 6),
#  'Barbados': (157, 'Barbados', 2),
#  'Burkina Faso': (158, 'Burkina Faso', 3),
#  'Chad': (159, 'Chad', 3),
#  'The Gambia': (160, 'The Gambia', 3),
#  'Philippines': (161, 'Philippines', 5),
#  'Armenia': (162, 'Armenia', 4),
#  'Zimbabwe': (163, 'Zimbabwe', 3),
#  'Niger': (164, 'Niger', 3),
#  'Madagascar': (165, 'Madagascar', 3),
#  'Serbia': (166, 'Serbia', 4),
#  'Equatorial Guinea': (167, 'Equatorial Guinea', 3),
#  'San Marino': (168, 'San Marino', 4),
#  'Tajikistan': (169, 'Tajikistan', 5),
#  'Oman': (170, 'Oman', 1),
#  'Poland': (171, 'Poland', 4),
#  'Nauru': (172, 'Nauru', 6),
#  'Palau': (173, 'Palau', 6),
#  'Liechtenstein': (174, 'Liechtenstein', 4),
#  'Vanuatu': (175, 'Vanuatu', 6),
#  'New Zealand': (176, 'New Zealand', 6),
#  'Guatemala': (177, 'Guatemala', 2),
#  'Nigeria': (178, 'Nigeria', 3),
#  'Seychelles ': (179, 'Seychelles ', 3),
#  'Malaysia': (180, 'Malaysia', 5),
#  'Brunei': (181, 'Brunei', 5),
#  'Jamaica': (182, 'Jamaica', 2),
#  'Austria': (183, 'Austria', 4),
#  'Honduras': (184, 'Honduras', 2),
#  'Yemen': (185, 'Yemen', 1)}

# %%
type_list = df['Item Type'].unique().tolist()

cur = conn.cursor()
try:
    execute_values(
        cur,
        "INSERT INTO product_type (name) VALUES %s RETURNING id, name",
        [(t,) for t in type_list],
    )
    inserted_types = cur.fetchall()
    types = {t[1]: t[0] for t in inserted_types}
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()
types
# Out:
# {'Snacks': 1,
#  'Cosmetics': 2,
#  'Fruits': 3,
#  'Personal Care': 4,
#  'Household': 5,
#  'Clothes': 6,
#  'Vegetables': 7,
#  'Office Supplies': 8,
#  'Beverages': 9,
#  'Meat': 10,
#  'Cereal': 11,
#  'Baby Food': 12}

# %%
# create dummy brand
cur = conn.cursor()
try:
    execute_values(
        cur,
        "INSERT INTO brand (name, logo, description) VALUES %s",
        [('dummy', '/assets/brand/logo.png', 'This is a placeholder brand for historical data.')]
    )
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()

# %%
from datetime import datetime
# create dummy user
cur = conn.cursor()
try:
    execute_values(
        cur,
        "INSERT INTO user_account (email, password_hash, created_at, last_login, is_admin) VALUES %s",
        [('test@test.com', 'asdfjghjkl', datetime.now().isoformat(), datetime.now().isoformat(), False)]
    )
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()

# %%
df[['Item Type', 'Unit Price', 'Unit Cost']].value_counts().reset_index(name='count')
# Out:
#           Item Type  Unit Price  Unit Cost  count
# 0   Office Supplies      651.21     524.96   8426
# 1            Cereal      205.70     117.11   8421
# 2         Baby Food      255.28     159.42   8407
# 3         Cosmetics      437.20     263.33   8370
# 4     Personal Care       81.73      56.67   8364
# 5              Meat      421.89     364.69   8320
# 6            Snacks      152.58      97.44   8308
# 7           Clothes      109.28      35.84   8304
# 8        Vegetables      154.06      90.93   8282
# 9         Household      668.27     502.54   8278
# 10           Fruits        9.33       6.92   8262
# 11        Beverages       47.45      31.79   8258

# %% [markdown]
# Every `Item Type`, `Unit Price`, `Unit Cost` are the same on each `Item Type`. So we can assume that these are the same products and should not duplicate them.

# %%
from random import randint
priority_map = {
    'L': 100,
    'M': 200,
    'H': 300,
    'C': 400
}
stock_values = [0,0,1,5,100,123,1000]
def serialize_order(row):
    # df variables: Item Type, Unit Price, Unit Cost

    product = {
        "name": "Dummy Product",
        "type": types[row['Item Type']],
        "brand": 1,
        "price": float(row['Unit Price']),
        "cost": float(row['Unit Cost']),
        "description": "N/A",
        "stock": stock_values[randint(0, len(stock_values) - 1)]
    }

    order = {
        "date": row["Order Date"],
        'ship_date': row['Ship Date'],
        'user_id': 1,
        'country_id': countries[row['Country']][0],
        'priority': priority_map[row['Order Priority']],
        'price':  float(row['Total Revenue']),
        'cost':   float(row['Total Cost']),
        'profit': float(row['Total Profit']),
    }

    order_item = {
        "order_id": None,
        "product_id": None,
        "amount": row["Units Sold"],
        "unit_price": row["Unit Price"]
    }
    return product, order, order_item

# %%
def get_or_create_product(product: dict):
    cur = conn.cursor()
    try:
        cur.execute(f"SELECT id FROM product WHERE price={product['price']} AND cost={product['cost']} AND type={product['type']} LIMIT 1")
        result = cur.fetchone()
        if result:
            conn.commit()
            return result[0]

        columns = ', '.join(product.keys())
        placeholders = ', '.join(['%s'] * len(product))
        
        cur.execute(
            f"INSERT INTO product ({columns}) VALUES ({placeholders}) RETURNING id",
            list(product.values())
        )
        product_id = cur.fetchone()[0]
        conn.commit()
        return product_id
    except Exception as e:
        conn.rollback()
        raise(e)

# %%
def create_order(order):
    cur = conn.cursor()
    try:
        columns = ', '.join(order.keys())
        placeholders = ', '.join(['%s'] * len(order))

        cur.execute(
            f"INSERT INTO orders ({columns}) VALUES ({placeholders}) RETURNING id",
            list(order.values())
        )
        order_id = cur.fetchone()[0]
        conn.commit()
        return order_id
    except Exception as e:
        conn.rollback()
        raise(e)

# %%
def create_order_item(order_item):
    cur = conn.cursor()
    try:
        columns = ', '.join(order_item.keys())
        placeholders = ', '.join(['%s'] * len(order_item))

        cur.execute(
            f"INSERT INTO order_item ({columns}) VALUES ({placeholders}) RETURNING id",
            list(order_item.values())
        )
        order_item_id = cur.fetchone()[0]
        conn.commit()
        return order_item_id
    except Exception as e:
        conn.rollback()
        raise(e)

# %%
from datetime import timedelta
success = 0
total = 100000
start_time = datetime.now()
for _, row in df.iterrows():
    p, o, oi = serialize_order(row.to_dict())
    p_id = get_or_create_product(p)
    o_id = create_order(o)
    oi['product_id'] = p_id
    oi['order_id'] = o_id
    oi_id = create_order_item(oi)
    success += 1
    if success % 500 == 0 and success > 0:
        current_time = datetime.now()
        elapsed_time = (current_time - start_time).total_seconds()
        progress = success / total
    
        if progress > 0:
            total_estimated_seconds = elapsed_time / progress
            remaining_seconds = total_estimated_seconds - elapsed_time
            remaining_time = str(timedelta(seconds=int(remaining_seconds)))
    
            print(f'Completed: {success} | '
                  f'Progress: {progress:.2%} | '
                  f'Time elapsed: {str(timedelta(seconds=int(elapsed_time)))} | '
                  f'Est. time remaining: {remaining_time}')
print(f'done')
# Out:
# Completed: 500 | Progress: 0.50% | Time elapsed: 0:00:03 | Est. time remaining: 0:10:29
# Completed: 1000 | Progress: 1.00% | Time elapsed: 0:00:06 | Est. time remaining: 0:10:08
# Completed: 1500 | Progress: 1.50% | Time elapsed: 0:00:09 | Est. time remaining: 0:10:10
# Completed: 2000 | Progress: 2.00% | Time elapsed: 0:00:11 | Est. time remaining: 0:09:43
# Completed: 2500 | Progress: 2.50% | Time elapsed: 0:00:14 | Est. time remaining: 0:09:16
# Completed: 3000 | Progress: 3.00% | Time elapsed: 0:00:16 | Est. time remaining: 0:09:01
# Completed: 3500 | Progress: 3.50% | Time elapsed: 0:00:19 | Est. time remaining: 0:08:51
# Completed: 4000 | Progress: 4.00% | Time elapsed: 0:00:21 | Est. time remaining: 0:08:40
# Completed: 4500 | Progress: 4.50% | Time elapsed: 0:00:24 | Est. time remaining: 0:08:33
# Completed: 5000 | Progress: 5.00% | Time elapsed: 0:00:26 | Est. time remaining: 0:08:24
# Completed: 5500 | Progress: 5.50% | Time elapsed: 0:00:29 | Est. time remaining: 0:08:18
# Completed: 6000 | Progress: 6.00% | Time elapsed: 0:00:31 | Est. time remaining: 0:08:11
# Completed: 6500 | Progress: 6.50% | Time elapsed: 0:00:33 | Est. time remaining: 0:08:06
# Completed: 7000 | Progress: 7.00% | Time elapsed: 0:00:36 | Est. time remaining: 0:08:05
# Completed: 7500 | Progress: 7.50% | Time elapsed: 0:00:38 | Est. time remaining: 0:07:59
# Completed: 8000 | Progress: 8.00% | Time elapsed: 0:00:41 | Est. time remaining: 0:07:54
# Completed: 8500 | Progress: 8.50% | Time elapsed: 0:00:43 | Est. time remaining: 0:07:49
# Completed: 9000 | Progress: 9.00% | Time elapsed: 0:00:46 | Est. time remaining: 0:07:45
# Completed: 9500 | Progress: 9.50% | Time elapsed: 0:00:48 | Est. time remaining: 0:07:40
# Completed: 10000 | Progress: 10.00% | Time elapsed: 0:00:50 | Est. time remaining: 0:07:37
# Completed: 10500 | Progress: 10.50% | Time elapsed: 0:00:53 | Est. time remaining: 0:07:33
# Completed: 11000 | Progress: 11.00% | Time elapsed: 0:00:55 | Est. time remaining: 0:07:30
# Completed: 11500 | Progress: 11.50% | Time elapsed: 0:00:58 | Est. time remaining: 0:07:26
# Completed: 12000 | Progress: 12.00% | Time elapsed: 0:01:00 | Est. time remaining: 0:07:22
# Completed: 12500 | Progress: 12.50% | Time elapsed: 0:01:02 | Est. time remaining: 0:07:17
# Completed: 13000 | Progress: 13.00% | Time elapsed: 0:01:04 | Est. time remaining: 0:07:13
# Completed: 13500 | Progress: 13.50% | Time elapsed: 0:01:06 | Est. time remaining: 0:07:08
# Completed: 14000 | Progress: 14.00% | Time elapsed: 0:01:09 | Est. time remaining: 0:07:04
# Completed: 14500 | Progress: 14.50% | Time elapsed: 0:01:11 | Est. time remaining: 0:07:00
# Completed: 15000 | Progress: 15.00% | Time elapsed: 0:01:13 | Est. time remaining: 0:06:57
# Completed: 15500 | Progress: 15.50% | Time elapsed: 0:01:16 | Est. time remaining: 0:06:55
# Completed: 16000 | Progress: 16.00% | Time elapsed: 0:01:19 | Est. time remaining: 0:06:55
# Completed: 16500 | Progress: 16.50% | Time elapsed: 0:01:22 | Est. time remaining: 0:06:58
# Completed: 17000 | Progress: 17.00% | Time elapsed: 0:01:26 | Est. time remaining: 0:07:01
# Completed: 17500 | Progress: 17.50% | Time elapsed: 0:01:29 | Est. time remaining: 0:07:02
# Completed: 18000 | Progress: 18.00% | Time elapsed: 0:01:32 | Est. time remaining: 0:06:59
# Completed: 18500 | Progress: 18.50% | Time elapsed: 0:01:34 | Est. time remaining: 0:06:56
# Completed: 19000 | Progress: 19.00% | Time elapsed: 0:01:37 | Est. time remaining: 0:06:56
# Completed: 19500 | Progress: 19.50% | Time elapsed: 0:01:40 | Est. time remaining: 0:06:53
# Completed: 20000 | Progress: 20.00% | Time elapsed: 0:01:42 | Est. time remaining: 0:06:48
# Completed: 20500 | Progress: 20.50% | Time elapsed: 0:01:44 | Est. time remaining: 0:06:45
# Completed: 21000 | Progress: 21.00% | Time elapsed: 0:01:46 | Est. time remaining: 0:06:41
# Completed: 21500 | Progress: 21.50% | Time elapsed: 0:01:49 | Est. time remaining: 0:06:38
# Completed: 22000 | Progress: 22.00% | Time elapsed: 0:01:51 | Est. time remaining: 0:06:36
# Completed: 22500 | Progress: 22.50% | Time elapsed: 0:01:55 | Est. time remaining: 0:06:36
# Completed: 23000 | Progress: 23.00% | Time elapsed: 0:01:57 | Est. time remaining: 0:06:34
# Completed: 23500 | Progress: 23.50% | Time elapsed: 0:02:00 | Est. time remaining: 0:06:32
# Completed: 24000 | Progress: 24.00% | Time elapsed: 0:02:03 | Est. time remaining: 0:06:29
# Completed: 24500 | Progress: 24.50% | Time elapsed: 0:02:06 | Est. time remaining: 0:06:28
# Completed: 25000 | Progress: 25.00% | Time elapsed: 0:02:09 | Est. time remaining: 0:06:28
# Completed: 25500 | Progress: 25.50% | Time elapsed: 0:02:14 | Est. time remaining: 0:06:32
# Completed: 26000 | Progress: 26.00% | Time elapsed: 0:02:19 | Est. time remaining: 0:06:36
# Completed: 26500 | Progress: 26.50% | Time elapsed: 0:02:22 | Est. time remaining: 0:06:34
# Completed: 27000 | Progress: 27.00% | Time elapsed: 0:02:24 | Est. time remaining: 0:06:31
# Completed: 27500 | Progress: 27.50% | Time elapsed: 0:02:27 | Est. time remaining: 0:06:28
# Completed: 28000 | Progress: 28.00% | Time elapsed: 0:02:30 | Est. time remaining: 0:06:25
# Completed: 28500 | Progress: 28.50% | Time elapsed: 0:02:32 | Est. time remaining: 0:06:22
# Completed: 29000 | Progress: 29.00% | Time elapsed: 0:02:35 | Est. time remaining: 0:06:19
# Completed: 29500 | Progress: 29.50% | Time elapsed: 0:02:37 | Est. time remaining: 0:06:17
# Completed: 30000 | Progress: 30.00% | Time elapsed: 0:02:40 | Est. time remaining: 0:06:13
# Completed: 30500 | Progress: 30.50% | Time elapsed: 0:02:42 | Est. time remaining: 0:06:09
# Completed: 31000 | Progress: 31.00% | Time elapsed: 0:02:44 | Est. time remaining: 0:06:05
# Completed: 31500 | Progress: 31.50% | Time elapsed: 0:02:46 | Est. time remaining: 0:06:02
# Completed: 32000 | Progress: 32.00% | Time elapsed: 0:02:48 | Est. time remaining: 0:05:58
# Completed: 32500 | Progress: 32.50% | Time elapsed: 0:02:51 | Est. time remaining: 0:05:55
# Completed: 33000 | Progress: 33.00% | Time elapsed: 0:02:53 | Est. time remaining: 0:05:52
# Completed: 33500 | Progress: 33.50% | Time elapsed: 0:02:56 | Est. time remaining: 0:05:50
# Completed: 34000 | Progress: 34.00% | Time elapsed: 0:02:58 | Est. time remaining: 0:05:47
# Completed: 34500 | Progress: 34.50% | Time elapsed: 0:03:01 | Est. time remaining: 0:05:45
# Completed: 35000 | Progress: 35.00% | Time elapsed: 0:03:05 | Est. time remaining: 0:05:43
# Completed: 35500 | Progress: 35.50% | Time elapsed: 0:03:08 | Est. time remaining: 0:05:42
# Completed: 36000 | Progress: 36.00% | Time elapsed: 0:03:11 | Est. time remaining: 0:05:39
# Completed: 36500 | Progress: 36.50% | Time elapsed: 0:03:13 | Est. time remaining: 0:05:37
# Completed: 37000 | Progress: 37.00% | Time elapsed: 0:03:16 | Est. time remaining: 0:05:34
# Completed: 37500 | Progress: 37.50% | Time elapsed: 0:03:19 | Est. time remaining: 0:05:32
# Completed: 38000 | Progress: 38.00% | Time elapsed: 0:03:22 | Est. time remaining: 0:05:30
# Completed: 38500 | Progress: 38.50% | Time elapsed: 0:03:25 | Est. time remaining: 0:05:27
# Completed: 39000 | Progress: 39.00% | Time elapsed: 0:03:27 | Est. time remaining: 0:05:25
# Completed: 39500 | Progress: 39.50% | Time elapsed: 0:03:30 | Est. time remaining: 0:05:22
# Completed: 40000 | Progress: 40.00% | Time elapsed: 0:03:33 | Est. time remaining: 0:05:20
# Completed: 40500 | Progress: 40.50% | Time elapsed: 0:03:37 | Est. time remaining: 0:05:18
# Completed: 41000 | Progress: 41.00% | Time elapsed: 0:03:39 | Est. time remaining: 0:05:16
# Completed: 41500 | Progress: 41.50% | Time elapsed: 0:03:42 | Est. time remaining: 0:05:13
# Completed: 42000 | Progress: 42.00% | Time elapsed: 0:03:45 | Est. time remaining: 0:05:11
# Completed: 42500 | Progress: 42.50% | Time elapsed: 0:03:48 | Est. time remaining: 0:05:08
# Completed: 43000 | Progress: 43.00% | Time elapsed: 0:03:50 | Est. time remaining: 0:05:06
# Completed: 43500 | Progress: 43.50% | Time elapsed: 0:03:53 | Est. time remaining: 0:05:03
# Completed: 44000 | Progress: 44.00% | Time elapsed: 0:03:56 | Est. time remaining: 0:05:00
# Completed: 44500 | Progress: 44.50% | Time elapsed: 0:03:59 | Est. time remaining: 0:04:58
# Completed: 45000 | Progress: 45.00% | Time elapsed: 0:04:01 | Est. time remaining: 0:04:55
# Completed: 45500 | Progress: 45.50% | Time elapsed: 0:04:04 | Est. time remaining: 0:04:53
# Completed: 46000 | Progress: 46.00% | Time elapsed: 0:04:07 | Est. time remaining: 0:04:50
# Completed: 46500 | Progress: 46.50% | Time elapsed: 0:04:10 | Est. time remaining: 0:04:47
# Completed: 47000 | Progress: 47.00% | Time elapsed: 0:04:12 | Est. time remaining: 0:04:45
# Completed: 47500 | Progress: 47.50% | Time elapsed: 0:04:15 | Est. time remaining: 0:04:42
# Completed: 48000 | Progress: 48.00% | Time elapsed: 0:04:18 | Est. time remaining: 0:04:40
# Completed: 48500 | Progress: 48.50% | Time elapsed: 0:04:21 | Est. time remaining: 0:04:37
# Completed: 49000 | Progress: 49.00% | Time elapsed: 0:04:24 | Est. time remaining: 0:04:34
# Completed: 49500 | Progress: 49.50% | Time elapsed: 0:04:26 | Est. time remaining: 0:04:32
# Completed: 50000 | Progress: 50.00% | Time elapsed: 0:04:29 | Est. time remaining: 0:04:29
# Completed: 50500 | Progress: 50.50% | Time elapsed: 0:04:32 | Est. time remaining: 0:04:26
# Completed: 51000 | Progress: 51.00% | Time elapsed: 0:04:35 | Est. time remaining: 0:04:24
# Completed: 51500 | Progress: 51.50% | Time elapsed: 0:04:38 | Est. time remaining: 0:04:22
# Completed: 52000 | Progress: 52.00% | Time elapsed: 0:04:41 | Est. time remaining: 0:04:19
# Completed: 52500 | Progress: 52.50% | Time elapsed: 0:04:43 | Est. time remaining: 0:04:16
# Completed: 53000 | Progress: 53.00% | Time elapsed: 0:04:46 | Est. time remaining: 0:04:14
# Completed: 53500 | Progress: 53.50% | Time elapsed: 0:04:49 | Est. time remaining: 0:04:11
# Completed: 54000 | Progress: 54.00% | Time elapsed: 0:04:51 | Est. time remaining: 0:04:08
# Completed: 54500 | Progress: 54.50% | Time elapsed: 0:04:55 | Est. time remaining: 0:04:06
# Completed: 55000 | Progress: 55.00% | Time elapsed: 0:04:58 | Est. time remaining: 0:04:03
# Completed: 55500 | Progress: 55.50% | Time elapsed: 0:05:00 | Est. time remaining: 0:04:01
# Completed: 56000 | Progress: 56.00% | Time elapsed: 0:05:03 | Est. time remaining: 0:03:58
# Completed: 56500 | Progress: 56.50% | Time elapsed: 0:05:06 | Est. time remaining: 0:03:55
# Completed: 57000 | Progress: 57.00% | Time elapsed: 0:05:08 | Est. time remaining: 0:03:53
# Completed: 57500 | Progress: 57.50% | Time elapsed: 0:05:11 | Est. time remaining: 0:03:50
# Completed: 58000 | Progress: 58.00% | Time elapsed: 0:05:13 | Est. time remaining: 0:03:47
# Completed: 58500 | Progress: 58.50% | Time elapsed: 0:05:16 | Est. time remaining: 0:03:44
# Completed: 59000 | Progress: 59.00% | Time elapsed: 0:05:18 | Est. time remaining: 0:03:41
# Completed: 59500 | Progress: 59.50% | Time elapsed: 0:05:20 | Est. time remaining: 0:03:38
# Completed: 60000 | Progress: 60.00% | Time elapsed: 0:05:23 | Est. time remaining: 0:03:35
# Completed: 60500 | Progress: 60.50% | Time elapsed: 0:05:26 | Est. time remaining: 0:03:33
# Completed: 61000 | Progress: 61.00% | Time elapsed: 0:05:28 | Est. time remaining: 0:03:30
# Completed: 61500 | Progress: 61.50% | Time elapsed: 0:05:31 | Est. time remaining: 0:03:27
# Completed: 62000 | Progress: 62.00% | Time elapsed: 0:05:34 | Est. time remaining: 0:03:25
# Completed: 62500 | Progress: 62.50% | Time elapsed: 0:05:37 | Est. time remaining: 0:03:22
# Completed: 63000 | Progress: 63.00% | Time elapsed: 0:05:40 | Est. time remaining: 0:03:19
# Completed: 63500 | Progress: 63.50% | Time elapsed: 0:05:42 | Est. time remaining: 0:03:16
# Completed: 64000 | Progress: 64.00% | Time elapsed: 0:05:44 | Est. time remaining: 0:03:14
# Completed: 64500 | Progress: 64.50% | Time elapsed: 0:05:47 | Est. time remaining: 0:03:11
# Completed: 65000 | Progress: 65.00% | Time elapsed: 0:05:49 | Est. time remaining: 0:03:08
# Completed: 65500 | Progress: 65.50% | Time elapsed: 0:05:52 | Est. time remaining: 0:03:05
# Completed: 66000 | Progress: 66.00% | Time elapsed: 0:05:54 | Est. time remaining: 0:03:02
# Completed: 66500 | Progress: 66.50% | Time elapsed: 0:05:57 | Est. time remaining: 0:03:00
# Completed: 67000 | Progress: 67.00% | Time elapsed: 0:06:00 | Est. time remaining: 0:02:57
# Completed: 67500 | Progress: 67.50% | Time elapsed: 0:06:03 | Est. time remaining: 0:02:55
# Completed: 68000 | Progress: 68.00% | Time elapsed: 0:06:06 | Est. time remaining: 0:02:52
# Completed: 68500 | Progress: 68.50% | Time elapsed: 0:06:08 | Est. time remaining: 0:02:49
# Completed: 69000 | Progress: 69.00% | Time elapsed: 0:06:11 | Est. time remaining: 0:02:47
# Completed: 69500 | Progress: 69.50% | Time elapsed: 0:06:14 | Est. time remaining: 0:02:44
# Completed: 70000 | Progress: 70.00% | Time elapsed: 0:06:17 | Est. time remaining: 0:02:41
# Completed: 70500 | Progress: 70.50% | Time elapsed: 0:06:20 | Est. time remaining: 0:02:39
# Completed: 71000 | Progress: 71.00% | Time elapsed: 0:06:23 | Est. time remaining: 0:02:36
# Completed: 71500 | Progress: 71.50% | Time elapsed: 0:06:25 | Est. time remaining: 0:02:33
# Completed: 72000 | Progress: 72.00% | Time elapsed: 0:06:28 | Est. time remaining: 0:02:30
# Completed: 72500 | Progress: 72.50% | Time elapsed: 0:06:30 | Est. time remaining: 0:02:28
# Completed: 73000 | Progress: 73.00% | Time elapsed: 0:06:33 | Est. time remaining: 0:02:25
# Completed: 73500 | Progress: 73.50% | Time elapsed: 0:06:35 | Est. time remaining: 0:02:22
# Completed: 74000 | Progress: 74.00% | Time elapsed: 0:06:37 | Est. time remaining: 0:02:19
# Completed: 74500 | Progress: 74.50% | Time elapsed: 0:06:40 | Est. time remaining: 0:02:17
# Completed: 75000 | Progress: 75.00% | Time elapsed: 0:06:42 | Est. time remaining: 0:02:14
# Completed: 75500 | Progress: 75.50% | Time elapsed: 0:06:45 | Est. time remaining: 0:02:11
# Completed: 76000 | Progress: 76.00% | Time elapsed: 0:06:47 | Est. time remaining: 0:02:08
# Completed: 76500 | Progress: 76.50% | Time elapsed: 0:06:49 | Est. time remaining: 0:02:05
# Completed: 77000 | Progress: 77.00% | Time elapsed: 0:06:52 | Est. time remaining: 0:02:03
# Completed: 77500 | Progress: 77.50% | Time elapsed: 0:06:54 | Est. time remaining: 0:02:00
# Completed: 78000 | Progress: 78.00% | Time elapsed: 0:06:56 | Est. time remaining: 0:01:57
# Completed: 78500 | Progress: 78.50% | Time elapsed: 0:06:58 | Est. time remaining: 0:01:54
# Completed: 79000 | Progress: 79.00% | Time elapsed: 0:07:01 | Est. time remaining: 0:01:51
# Completed: 79500 | Progress: 79.50% | Time elapsed: 0:07:03 | Est. time remaining: 0:01:49
# Completed: 80000 | Progress: 80.00% | Time elapsed: 0:07:06 | Est. time remaining: 0:01:46
# Completed: 80500 | Progress: 80.50% | Time elapsed: 0:07:08 | Est. time remaining: 0:01:43
# Completed: 81000 | Progress: 81.00% | Time elapsed: 0:07:10 | Est. time remaining: 0:01:41
# Completed: 81500 | Progress: 81.50% | Time elapsed: 0:07:12 | Est. time remaining: 0:01:38
# Completed: 82000 | Progress: 82.00% | Time elapsed: 0:07:15 | Est. time remaining: 0:01:35
# Completed: 82500 | Progress: 82.50% | Time elapsed: 0:07:17 | Est. time remaining: 0:01:32
# Completed: 83000 | Progress: 83.00% | Time elapsed: 0:07:19 | Est. time remaining: 0:01:30
# Completed: 83500 | Progress: 83.50% | Time elapsed: 0:07:21 | Est. time remaining: 0:01:27
# Completed: 84000 | Progress: 84.00% | Time elapsed: 0:07:23 | Est. time remaining: 0:01:24
# Completed: 84500 | Progress: 84.50% | Time elapsed: 0:07:26 | Est. time remaining: 0:01:21
# Completed: 85000 | Progress: 85.00% | Time elapsed: 0:07:28 | Est. time remaining: 0:01:19
# Completed: 85500 | Progress: 85.50% | Time elapsed: 0:07:30 | Est. time remaining: 0:01:16
# Completed: 86000 | Progress: 86.00% | Time elapsed: 0:07:32 | Est. time remaining: 0:01:13
# Completed: 86500 | Progress: 86.50% | Time elapsed: 0:07:34 | Est. time remaining: 0:01:10
# Completed: 87000 | Progress: 87.00% | Time elapsed: 0:07:37 | Est. time remaining: 0:01:08
# Completed: 87500 | Progress: 87.50% | Time elapsed: 0:07:39 | Est. time remaining: 0:01:05
# Completed: 88000 | Progress: 88.00% | Time elapsed: 0:07:41 | Est. time remaining: 0:01:02
# Completed: 88500 | Progress: 88.50% | Time elapsed: 0:07:43 | Est. time remaining: 0:01:00
# Completed: 89000 | Progress: 89.00% | Time elapsed: 0:07:46 | Est. time remaining: 0:00:57
# Completed: 89500 | Progress: 89.50% | Time elapsed: 0:07:48 | Est. time remaining: 0:00:54
# Completed: 90000 | Progress: 90.00% | Time elapsed: 0:07:50 | Est. time remaining: 0:00:52
# Completed: 90500 | Progress: 90.50% | Time elapsed: 0:07:52 | Est. time remaining: 0:00:49
# Completed: 91000 | Progress: 91.00% | Time elapsed: 0:07:55 | Est. time remaining: 0:00:47
# Completed: 91500 | Progress: 91.50% | Time elapsed: 0:07:57 | Est. time remaining: 0:00:44
# Completed: 92000 | Progress: 92.00% | Time elapsed: 0:07:59 | Est. time remaining: 0:00:41
# Completed: 92500 | Progress: 92.50% | Time elapsed: 0:08:02 | Est. time remaining: 0:00:39
# Completed: 93000 | Progress: 93.00% | Time elapsed: 0:08:04 | Est. time remaining: 0:00:36
# Completed: 93500 | Progress: 93.50% | Time elapsed: 0:08:06 | Est. time remaining: 0:00:33
# Completed: 94000 | Progress: 94.00% | Time elapsed: 0:08:08 | Est. time remaining: 0:00:31
# Completed: 94500 | Progress: 94.50% | Time elapsed: 0:08:11 | Est. time remaining: 0:00:28
# Completed: 95000 | Progress: 95.00% | Time elapsed: 0:08:13 | Est. time remaining: 0:00:25
# Completed: 95500 | Progress: 95.50% | Time elapsed: 0:08:15 | Est. time remaining: 0:00:23
# Completed: 96000 | Progress: 96.00% | Time elapsed: 0:08:17 | Est. time remaining: 0:00:20
# Completed: 96500 | Progress: 96.50% | Time elapsed: 0:08:20 | Est. time remaining: 0:00:18
# Completed: 97000 | Progress: 97.00% | Time elapsed: 0:08:22 | Est. time remaining: 0:00:15
# Completed: 97500 | Progress: 97.50% | Time elapsed: 0:08:24 | Est. time remaining: 0:00:12
# Completed: 98000 | Progress: 98.00% | Time elapsed: 0:08:26 | Est. time remaining: 0:00:10
# Completed: 98500 | Progress: 98.50% | Time elapsed: 0:08:28 | Est. time remaining: 0:00:07
# Completed: 99000 | Progress: 99.00% | Time elapsed: 0:08:30 | Est. time remaining: 0:00:05
# Completed: 99500 | Progress: 99.50% | Time elapsed: 0:08:33 | Est. time remaining: 0:00:02
# Completed: 100000 | Progress: 100.00% | Time elapsed: 0:08:35 | Est. time remaining: 0:00:00
# done

# %%
from faker import Faker
fake = Faker()

def fake_user():
    email = fake.email()
    passhash = hash(email)
    created = fake.date_time_this_year()
    last_login = fake.date_time_between_dates(created, datetime.now())
    return (email, passhash, created.isoformat(), last_login.isoformat())
fake_user()
# Out:
# ('jordangary@example.com',
#  1591980521699660303,
#  '2025-01-25T10:30:49.572955',
#  '2025-02-09T15:55:05.433939')

# %%
cur = conn.cursor()
try:
    execute_values(
        cur,
        "INSERT INTO user_account (email, password_hash, created_at, last_login) VALUES %s",
        [fake_user() for i in range(199)],
    )
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()

# %%
# %%sql
# SELECT COUNT(*) FROM user_account
# Out:
#    count
# 0    200

# %%
# %%sql
# SELECT COUNT(*) FROM product
# Out:
#    count
# 0     12

# %%
review_randoms = [sorted([max(1, min(5, randint(-3,9))) for i in range(7)]) for i in range(12)]
for l in review_randoms:
    print(f'{l} - avg:{sum(l)/len(l):02f}')
# Out:
# [3, 3, 4, 5, 5, 5, 5] - avg:4.285714
# [1, 1, 2, 4, 5, 5, 5] - avg:3.285714
# [1, 1, 1, 1, 1, 3, 3] - avg:1.571429
# [1, 1, 1, 1, 5, 5, 5] - avg:2.714286
# [1, 1, 3, 4, 5, 5, 5] - avg:3.428571
# [1, 4, 5, 5, 5, 5, 5] - avg:4.285714
# [1, 1, 3, 3, 5, 5, 5] - avg:3.285714
# [1, 1, 1, 4, 5, 5, 5] - avg:3.142857
# [1, 1, 1, 2, 3, 5, 5] - avg:2.571429
# [1, 1, 1, 2, 4, 5, 5] - avg:2.714286
# [1, 1, 1, 2, 5, 5, 5] - avg:2.857143
# [1, 1, 1, 5, 5, 5, 5] - avg:3.285714

# %%
def fake_product_review(user_id, product_id):
    review_list = review_randoms[product_id - 1]
    
    return (
        user_id,
        product_id,
        review_list[randint(0, len(review_list) - 1)],
        fake.text(max_nb_chars=1024)
    )

# %%
def create_product_reviews(reviews):
    cur = conn.cursor()
    try:
        execute_values(
            cur,
            "INSERT INTO product_review (user_id, product_id, rating, review) VALUES %s",
            reviews
        )
        conn.commit()
    except Exception as e:
        print(e)
        conn.rollback()

# %%
for product_id in range(1, 13):
    reviews = [fake_product_review(i + 1, product_id) for i in range(200)]
    create_product_reviews(reviews)

# %%
# %%sql
# SELECT COUNT(*) FROM product_review;
# Out:
#    count
# 0   2400

# %%
# %%sql
# -- Product Review Aggregation
# SELECT
#     p.id AS product_id,
#     pt.name as product_type,
#     p.name as product_name,
#     COALESCE(AVG(pr.rating), 0) AS average_rating
# FROM
#     product p
# JOIN
#     product_review pr ON p.id = pr.product_id
# JOIN
#     product_type pt ON p.type = pt.id
# GROUP BY
#     p.id, pt.name, p.name
# ORDER BY
#     average_rating DESC;
# --     p.id ASC;
# Out:
#     product_id     product_type   product_name  average_rating
# 0            6          Clothes  Dummy Product           4.345
# 1            1           Snacks  Dummy Product           4.285
# 2            5        Household  Dummy Product           3.495
# 3            2        Cosmetics  Dummy Product           3.380
# 4            7       Vegetables  Dummy Product           3.280
# 5           12        Baby Food  Dummy Product           3.220
# 6            8  Office Supplies  Dummy Product           3.205
# 7           11           Cereal  Dummy Product           2.995
# 8            4    Personal Care  Dummy Product           2.720
# 9           10             Meat  Dummy Product           2.600
# 10           9        Beverages  Dummy Product           2.535
# 11           3           Fruits  Dummy Product           1.620

# %%
# %%sql
# -- Total Sales by Country
# SELECT
#     c.name AS country_name,
#     TO_CHAR(o.date, 'YYYY-MM') AS order_month,
#     SUM(o.price) AS total_sales,
#     COUNT(o.id) AS order_count
# FROM
#     orders o
# JOIN
#     country c ON o.country_id = c.id
# GROUP BY
#     c.name, TO_CHAR(o.date, 'YYYY-MM')
# ORDER BY
#     c.name, order_month;
# Out:
#     country_name order_month   total_sales  order_count
# 0     Azerbaijan     2010-01  2.047518e+08          157
# 1     Azerbaijan     2010-02  1.794266e+08          121
# 2     Azerbaijan     2010-03  1.638187e+08          133
# 3     Azerbaijan     2010-04  1.819031e+08          139
# 4     Azerbaijan     2010-05  1.719495e+08          119
# ..           ...         ...           ...          ...
# 632       Turkey     2017-03  2.478024e+07           21
# 633       Turkey     2017-04  4.766108e+07           37
# 634       Turkey     2017-05  9.846162e+06           17
# 635       Turkey     2017-06  4.070480e+07           23
# 636       Turkey     2017-07  4.811439e+07           29
#
# [637 rows x 4 columns]

# %%
df_sql1.pivot_table(
    index='order_month',
    columns='country_name',
    values='total_sales',
    fill_value=0
)
# Out:
# country_name    Azerbaijan        Belize       Denmark       Germany  \
# order_month
# 2010-01       2.047518e+08  3.593405e+08  1.940823e+08  1.219499e+08
# 2010-02       1.794266e+08  3.476981e+08  1.839257e+08  9.922286e+07
# 2010-03       1.638187e+08  3.532424e+08  2.111500e+08  1.272302e+08
# 2010-04       1.819031e+08  4.177550e+08  2.283509e+08  1.309267e+08
# 2010-05       1.719495e+08  3.219215e+08  2.122861e+08  1.133555e+08
# ...                    ...           ...           ...           ...
# 2017-03       1.744848e+08  3.404760e+08  2.020492e+08  1.356433e+08
# 2017-04       2.130102e+08  3.632238e+08  1.936739e+08  1.005377e+08
# 2017-05       2.290722e+08  4.044962e+08  2.373231e+08  1.158848e+08
# 2017-06       1.679532e+08  3.859838e+08  1.794593e+08  1.131085e+08
# 2017-07       1.572865e+08  3.702253e+08  2.721560e+08  7.061134e+07
#
# country_name        Panama  Sao Tome and Principe       Turkey
# order_month
# 2010-01       1.462920e+08           3.619481e+08  42725684.40
# 2010-02       1.581915e+08           3.660615e+08  17381818.90
# 2010-03       1.472139e+08           3.633685e+08  20169601.30
# 2010-04       1.579042e+08           3.566669e+08  20467880.98
# 2010-05       1.376221e+08           4.079249e+08  38518528.54
# ...                    ...                    ...          ...
# 2017-03       1.399185e+08           3.692322e+08  24780239.95
# 2017-04       1.812459e+08           4.002989e+08  47661078.15
# 2017-05       1.792625e+08           3.606095e+08   9846161.61
# 2017-06       1.026656e+08           4.276991e+08  40704797.08
# 2017-07       1.816381e+08           3.458825e+08  48114393.20
#
# [91 rows x 7 columns]

# %%
# %%sql
# -- Total Sales by Region
# SELECT
#     r.name as region_name,
#     TO_CHAR(o.date, 'YYYY-MM') AS order_month,
#     SUM(o.price) AS total_sales,
#     COUNT(o.id) AS order_count
# FROM
#     orders o
# JOIN
#     country c ON o.country_id = c.id
# JOIN
#     region r on c.region_id = r.id
# GROUP BY
#     r.name, TO_CHAR(o.date, 'YYYY-MM')
# ORDER BY
#     r.name, order_month;
# Out:
#                            region_name order_month   total_sales  order_count
# 0    Central America and the Caribbean     2010-01  5.056324e+08          392
# 1    Central America and the Caribbean     2010-02  5.058896e+08          379
# 2    Central America and the Caribbean     2010-03  5.004563e+08          393
# 3    Central America and the Caribbean     2010-04  5.756592e+08          394
# 4    Central America and the Caribbean     2010-05  4.595436e+08          356
# ..                                 ...         ...           ...          ...
# 359                 Sub-Saharan Africa     2017-03  3.692322e+08          265
# 360                 Sub-Saharan Africa     2017-04  4.002989e+08          275
# 361                 Sub-Saharan Africa     2017-05  3.606095e+08          283
# 362                 Sub-Saharan Africa     2017-06  4.276991e+08          296
# 363                 Sub-Saharan Africa     2017-07  3.458825e+08          274
#
# [364 rows x 4 columns]

# %%
df_sql_region.pivot_table(
    index='order_month',
    columns='region_name',
    values='total_sales',
    fill_value=0
)
# Out:
# region_name  Central America and the Caribbean        Europe  \
# order_month
# 2010-01                           5.056324e+08  3.160322e+08
# 2010-02                           5.058896e+08  2.831486e+08
# 2010-03                           5.004563e+08  3.383801e+08
# 2010-04                           5.756592e+08  3.592776e+08
# 2010-05                           4.595436e+08  3.256416e+08
# ...                                        ...           ...
# 2017-03                           4.803946e+08  3.376925e+08
# 2017-04                           5.444697e+08  2.942116e+08
# 2017-05                           5.837587e+08  3.532080e+08
# 2017-06                           4.886494e+08  2.925679e+08
# 2017-07                           5.518633e+08  3.427673e+08
#
# region_name  Middle East and North Africa  Sub-Saharan Africa
# order_month
# 2010-01                      2.474775e+08        3.619481e+08
# 2010-02                      1.968084e+08        3.660615e+08
# 2010-03                      1.839883e+08        3.633685e+08
# 2010-04                      2.023710e+08        3.566669e+08
# 2010-05                      2.104680e+08        4.079249e+08
# ...                                   ...                 ...
# 2017-03                      1.992651e+08        3.692322e+08
# 2017-04                      2.606712e+08        4.002989e+08
# 2017-05                      2.389184e+08        3.606095e+08
# 2017-06                      2.086580e+08        4.276991e+08
# 2017-07                      2.054009e+08        3.458825e+08
#
# [91 rows x 4 columns]

# %%
# %%sql
# -- Total Sales by Product
# SELECT
#     p.id AS product_id,
#     p.name AS product_name,
#     TO_CHAR(o.date, 'YYYY-MM') AS order_month,
#     SUM(oi.amount) AS units_sold,
#     SUM(oi.amount * oi.unit_price) AS total_sales
# FROM
#     product p
# JOIN
#     order_item oi ON p.id = oi.product_id
# JOIN
#     orders o ON oi.order_id = o.id
# GROUP BY
#     p.id, p.name, TO_CHAR(o.date, 'YYYY-MM')
# ORDER BY
#     p.name, order_month;
# Out:
#       product_id   product_name order_month  units_sold   total_sales
# 0             10  Dummy Product     2010-01      262640  1.108052e+08
# 1              4  Dummy Product     2010-01      430810  3.521010e+07
# 2              8  Dummy Product     2010-01      562564  3.663473e+08
# 3             11  Dummy Product     2010-01      496213  1.020710e+08
# 4              5  Dummy Product     2010-01      429794  2.872184e+08
# ...          ...            ...         ...         ...           ...
# 1087           7  Dummy Product     2017-07      355860  5.482379e+07
# 1088           4  Dummy Product     2017-07      428835  3.504868e+07
# 1089          10  Dummy Product     2017-07      365147  1.540519e+08
# 1090           6  Dummy Product     2017-07      449951  4.917065e+07
# 1091           2  Dummy Product     2017-07      545909  2.386714e+08
#
# [1092 rows x 5 columns]

# %%
df_sql2.pivot_table(
    index='order_month',
    columns='product_id',
    values='total_sales'
)
# Out:
# product_id            1            2           3            4             5   \
# order_month
# 2010-01      72845506.50  203572998.8  4787866.77  35210101.30  2.872184e+08
# 2010-02      62244705.84  184568789.2  3857049.99  30659620.09  2.913069e+08
# 2010-03      84957306.90  203071967.6  4520842.17  39753390.27  2.458218e+08
# 2010-04      64148751.66  222797120.0  4186333.68  32970045.46  3.118876e+08
# 2010-05      73513654.32  194722759.2  4627754.64  34264321.74  2.974009e+08
# ...                  ...          ...         ...          ...           ...
# 2017-03      69184501.98  177170490.8  3959418.75  43834986.47  2.787194e+08
# 2017-04      61109968.38  265132070.4  4020978.09  43046700.62  2.669084e+08
# 2017-05      54941006.40  184318710.8  4475619.66  36967786.68  3.268696e+08
# 2017-06      74728191.12  186114728.4  3640901.88  34527083.69  3.001575e+08
# 2017-07      86135682.24  238671414.8  4384857.42  35048684.55  3.091437e+08
#
# product_id            6            7             8            9   \
# order_month
# 2010-01      44040604.96  75345353.90  3.663473e+08  24287235.05
# 2010-02      50547791.84  80370637.04  2.941040e+08  20716100.60
# 2010-03      44527010.24  64752958.60  2.648933e+08  20371898.30
# 2010-04      47956544.48  55680211.14  3.481037e+08  21109128.95
# 2010-05      58454636.96  70084204.90  2.725887e+08  15789177.30
# ...                  ...          ...           ...          ...
# 2017-03      45664177.92  84352163.68  2.580752e+08  23351378.70
# 2017-04      50912677.76  75679355.98  3.734500e+08  19496445.80
# 2017-05      49114693.92  75846357.02  3.365271e+08  25425987.60
# 2017-06      53512339.68  74135366.66  2.787589e+08  19848192.65
# 2017-07      49170645.28  54823791.60  2.734125e+08  22217940.55
#
# product_id             10           11            12
# order_month
# 2010-01      1.108052e+08  102071014.1  1.045586e+08
# 2010-02      1.426566e+08   91181050.4  9.969475e+07
# 2010-03      1.754084e+08   99334998.4  1.387794e+08
# 2010-04      1.732069e+08   86371167.3  1.255572e+08
# 2010-05      1.853856e+08   87341042.8  1.094053e+08
# ...                   ...          ...           ...
# 2017-03      2.136118e+08   85685569.2  1.029754e+08
# 2017-04      1.288304e+08  106184808.4  1.048795e+08
# 2017-05      2.110981e+08  109432605.7  1.214770e+08
# 2017-06      1.521458e+08   96079590.2  1.439258e+08
# 2017-07      1.540519e+08   91707231.0  1.271458e+08
#
# [91 rows x 12 columns]
